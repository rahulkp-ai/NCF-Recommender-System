# %% [markdown]
# | Metric               | Scratch NCF (NumPy) | PyTorch NCF (MPS) | Δ / Target              |
# |---------------------|--------------------|-------------------|-------------------------|
# | Final BCE Loss      | 0.6133             | 0.6111            | 0.0022 (<0.01 target)   |
# | Hit@10 (val)        | 0.6279             | 0.6293            | 0.22% (<2% target)      |
# | NDCG@10 (test)      | —                  | 0.3541            | —                       |
# | Avg Epoch Time      | ~88.5s             | ~6.9s             | ~12.8× speedup          |
# | Total Training Time | 29m 31s            | 2m 17s            | ~12.9× speedup          |
# | Parameters          | 1,228,800          | 1,228,800         | 0 (Identical)           |
# | Architecture        | GMF+MLP            | GMF+MLP           | 0 (Identical)           |
